# %%
import yfinance as yf
import pandas as pd
import indices
indices = indices.nifty_sectors
#indices = ['^CNXMETAL','NIFTY_FIN_SERVICE.NS','^CNXENERGY','^NSEBANK','^CNXFMCG','^CNXPHARMA','^CNXIT','^CNXAUTO']

#df = yf.download(tickers=indices,period='1d',interval='1d')
#display(df)

# %%
intrvl='5m'
quantity=0
add_ns=1


#def max_daily_change(indices, intrvl='1d', quantity=0, add_ns=1):

df = yf.download(tickers=indices, period='1d', interval=intrvl)

df = df.dropna()
df = df.iloc[-1]
df = pd.DataFrame(df[["Open", "High", "Low", "Close"]])
df = df.round(decimals=2)

# print(df.index)
df = df.T
arr = []
for i in df['Open']:
    arr.append(i)
df2 = pd.DataFrame(arr, columns=['Name'])
df2.set_index('Name', inplace=True)
# display(df2)
arr = []
for i in df.iloc[-1]['Open']:
    arr.append(i)
df2['Open'] = arr
arr = []
for i in df.iloc[-1]['High']:
    arr.append(i)
df2['High'] = arr
arr = []
for i in df.iloc[-1]['Low']:
    arr.append(i)
df2['Low'] = arr
arr = []
for i in df.iloc[-1]['Close']:
    arr.append(i)
df2['Close'] = arr

temp = (df2['High'] + df2['Low'])/2
df2['Average'] = temp

temp = ((df2['High'] - df2['Low'])*100) / df2['Average']
df2['InDay%Change'] = temp

temp = (df2['Open']-df2['Close'])
df2['Diff'] = temp

final_df = df2.sort_values(by=['InDay%Change'], ascending=False)
a = ''

"""
if quantity == 0:
    for i in final_df.index:
        print(i[:-3])
        if '&' in i:
            i = i.replace('&', '_')
        if add_ns == 0:
            a += ' \n  '+i
        else:
            a += ' \n  '+i[:-3]
    a = a[3:] if add_ns == 1 else a

else:
    for i in range(quantity):
        j = (final_df.index[i])[:-3]
        print(j)
        if '&' in j:
            j = j.replace('&', '_')
        a += ',  '+j
    a = a[3:]


"""
# Out:
# [*********************100%***********************]  8 of 8 completed
# "\nif quantity == 0:\n    for i in final_df.index:\n        print(i[:-3])\n        if '&' in i:\n            i = i.replace('&', '_')\n        if add_ns == 0:\n            a += ' \n  '+i\n        else:\n            a += ' \n  '+i[:-3]\n    a = a[3:] if add_ns == 1 else a\n\nelse:\n    for i in range(quantity):\n        j = (final_df.index[i])[:-3]\n        print(j)\n        if '&' in j:\n            j = j.replace('&', '_')\n        a += ',  '+j\n    a = a[3:]\n\n\n"

# %%
final_df
# Out:
#                           Open      High       Low     Close    Average  \
# Name
# ^CNXENERGY            20379.85  20384.80  20347.25  20350.80  20366.025
# ^NSEBANK              35223.75  35247.00  35185.95  35207.35  35216.475
# ^CNXMETAL              5289.85   5291.05   5282.40   5288.55   5286.725
# NIFTY_FIN_SERVICE.NS  16696.90  16704.15  16678.35  16688.25  16691.250
# ^CNXAUTO              10670.40  10674.05  10661.25  10667.15  10667.650
# ^CNXIT                26919.35  26936.45  26916.15  26936.35  26926.300
# ^CNXPHARMA            14110.65  14110.70  14102.15  14107.55  14106.425
# ^CNXFMCG              35106.55  35115.60  35096.70  35103.15  35106.150
#
#                       InDay%Change   Diff
# Name
# ^CNXENERGY                0.184376  29.05
# ^NSEBANK                  0.173356  16.40
# ^CNXMETAL                 0.163617   1.30
# NIFTY_FIN_SERVICE.NS      0.154572   8.65
# ^CNXAUTO                  0.119989   3.25
# ^CNXIT                    0.075391 -17.00
# ^CNXPHARMA                0.060611   3.10
# ^CNXFMCG                  0.053837   3.40

# %%
pos = []
neg = []
for i in range(len(final_df.index)):
    if(final_df.iloc[i]['Diff'] > 0):
        pos.append(final_df.index[i])
    else:
        neg.append(final_df.index[i])
print(pos)
print(neg)
# Out:
# ['^CNXENERGY', '^NSEBANK', '^CNXMETAL', 'NIFTY_FIN_SERVICE.NS', '^CNXAUTO', '^CNXPHARMA', '^CNXFMCG']
# ['^CNXIT']
