# %%
import yfinance as yf
import indices
import pandas as pd
indices = indices.nifty50
import tsend

def ns(x):
    return x+'.NS'


df = yf.download(tickers=list(map(ns, indices)), period='1d',interval='5m')
df = df.dropna()
df = df.iloc[-1]
df = pd.DataFrame(df[["Open", "High", "Low", "Close","Volume"]])
df = df.round(decimals=2)
#print(df.index)

df = df.T

arr = []
for i in df['Open']:
    arr.append(i)
    
df2 = pd.DataFrame(arr,columns=['Name'])
df2.set_index('Name', inplace=True)
#display(df2)
arr = []
for i in df.iloc[-1]['Open']:
    arr.append(i)
df2['Open'] = arr
arr = []
for i in df.iloc[-1]['High']:
    arr.append(i) 
df2['High'] = arr
arr = []
for i in df.iloc[-1]['Low']:
    arr.append(i) 
df2['Low'] = arr
arr = []
for i in df.iloc[-1]['Close']:
    arr.append(i)
df2['Close'] = arr
arr = []
for i in df.iloc[-1]['Volume']:
    arr.append(i)
df2['Volume'] = arr
temp = (df2['High'] + df2['Close'])/2
df2['Average'] = temp
temp = ((df2['High'] - df2['Low'])*100) / df2['Average']



df2['InDay%Change'] = temp

final_df = df2.sort_values(by=['InDay%Change'],ascending=False)

display(final_df)
# Out:
# [*********************100%***********************]  50 of 50 completed
#                    Open      High       Low     Close   Volume    Average  \
# Name
# SBILIFE.NS       982.40    982.40    980.00    980.00  13168.0    981.200
# AXISBANK.NS      736.20    737.15    736.20    736.80  12661.0    736.975
# UPL.NS           822.50    822.50    821.45    821.50  11471.0    822.000
# INFY.NS         1372.40   1373.70   1372.00   1373.00  13759.0   1373.350
# BAJAJFINSV.NS  11746.95  11755.00  11742.30  11751.05    182.0  11753.025
# BHARTIARTL.NS    531.05    531.60    531.05    531.40  26507.0    531.500
# HINDALCO.NS      393.60    393.60    393.20    393.35  13997.0    393.475
# DIVISLAB.NS     4236.70   4239.00   4234.70   4235.00    805.0   4237.000
# MARUTI.NS       7126.00   7132.75   7126.00   7132.50    789.0   7132.625
# INDUSINDBK.NS   1014.05   1015.00   1014.05   1014.85  14442.0   1014.925
# ADANIPORTS.NS    817.25    817.30    816.55    816.55  20044.0    816.925
# IOC.NS           110.70    110.75    110.65    110.70  21506.0    110.725
# HDFCLIFE.NS      670.05    670.20    669.60    669.95   7983.0    670.075
# TITAN.NS        1580.05   1580.95   1579.60   1579.70  15925.0   1580.325
# BAJFINANCE.NS   5805.00   5809.90   5805.00   5809.90   2934.0   5809.900
# KOTAKBANK.NS    1780.40   1781.50   1780.00   1780.70   7265.0   1781.100
# HEROMOTOCO.NS   2977.50   2979.00   2976.55   2978.80   1328.0   2978.900
# HDFCBANK.NS     1498.65   1498.85   1497.65   1498.85   3488.0   1498.850
# TECHM.NS        1011.30   1011.80   1011.00   1011.00  10037.0   1011.400
# ULTRACEMCO.NS   6610.85   6615.45   6610.25   6613.25    401.0   6614.350
# TATACONSUM.NS    670.30    670.50    670.00    670.10   3136.0    670.300
# SUNPHARMA.NS     673.75    674.00    673.50    673.70   1806.0    673.850
# NESTLEIND.NS   17707.20  17712.75  17700.00  17703.15    196.0  17707.950
# JSWSTEEL.NS      697.65    697.80    697.30    697.40  27714.0    697.600
# ITC.NS           210.95    211.05    210.90    211.05  94142.0    211.050
# GRASIM.NS       1439.10   1439.65   1438.65   1439.20   4555.0   1439.425
# SBIN.NS          433.95    434.10    433.80    434.10  31638.0    434.100
# COALINDIA.NS     149.10    149.20    149.10    149.15  20622.0    149.175
# SHREECEM.NS    27921.95  27921.95  27903.50  27917.50     13.0  27919.725
# BPCL.NS          470.90    471.10    470.80    470.85   4625.0    470.975
# HCLTECH.NS       942.35    942.80    942.20    942.55   6155.0    942.675
# TATASTEEL.NS    1114.25   1114.85   1114.15   1114.20  18175.0   1114.525
# ICICIBANK.NS     645.95    646.10    645.70    646.00  34142.0    646.050
# ASIANPAINT.NS   2912.25   2914.00   2912.25   2913.25   1838.0   2913.625
# HINDUNILVR.NS   2361.10   2361.45   2360.10   2361.30   1937.0   2361.375
# TATAMOTORS.NS    319.55    319.55    319.40    319.50  11301.0    319.525
# NTPC.NS          110.85    110.85    110.80    110.85   1640.0    110.850
# LT.NS           1463.35   1464.00   1463.35   1464.00   5761.0   1464.000
# POWERGRID.NS     225.85    225.90    225.80    225.80    931.0    225.850
# ONGC.NS          116.55    116.60    116.55    116.55  25056.0    116.575
# DRREDDY.NS      5298.00   5299.00   5297.00   5297.10    453.0   5298.050
# HDFC.NS         2548.20   2548.20   2547.25   2547.90  15181.0   2548.050
# CIPLA.NS         953.15    953.50    953.15    953.50    993.0    953.500
# TCS.NS          3124.30   3125.00   3124.00   3124.85   2244.0   3124.925
# BAJAJ-AUTO.NS   4247.90   4249.00   4247.90   4247.90     68.0   4248.450
# RELIANCE.NS     2171.50   2172.00   2171.50   2171.50  34186.0   2171.750
# EICHERMOT.NS    2675.35   2675.85   2675.35   2675.85    591.0   2675.850
# M&M.NS           804.45    804.45    804.30    804.35   3198.0    804.400
# WIPRO.NS         537.45    537.45    537.35    537.35   2790.0    537.400
# BRITANNIA.NS    3475.45   3475.45   3475.00   3475.00    520.0   3475.225
#
#                InDay%Change
# Name
# SBILIFE.NS         0.244598
# AXISBANK.NS        0.128905
# UPL.NS             0.127737
# INFY.NS            0.123785
# BAJAJFINSV.NS      0.108057
# BHARTIARTL.NS      0.103481
# HINDALCO.NS        0.101658
# DIVISLAB.NS        0.101487
# MARUTI.NS          0.094636
# INDUSINDBK.NS      0.093603
# ADANIPORTS.NS      0.091808
# IOC.NS             0.090314
# HDFCLIFE.NS        0.089542
# TITAN.NS           0.085425
# BAJFINANCE.NS      0.084339
# KOTAKBANK.NS       0.084218
# HEROMOTOCO.NS      0.082245
# HDFCBANK.NS        0.080061
# TECHM.NS           0.079098
# ULTRACEMCO.NS      0.078617
# TATACONSUM.NS      0.074593
# SUNPHARMA.NS       0.074200
# NESTLEIND.NS       0.072002
# JSWSTEEL.NS        0.071674
# ITC.NS             0.071073
# GRASIM.NS          0.069472
# SBIN.NS            0.069109
# COALINDIA.NS       0.067035
# SHREECEM.NS        0.066082
# BPCL.NS            0.063698
# HCLTECH.NS         0.063649
# TATASTEEL.NS       0.062807
# ICICIBANK.NS       0.061915
# ASIANPAINT.NS      0.060063
# HINDUNILVR.NS      0.057170
# TATAMOTORS.NS      0.046945
# NTPC.NS            0.045106
# LT.NS              0.044399
# POWERGRID.NS       0.044277
# ONGC.NS            0.042891
# DRREDDY.NS         0.037750
# HDFC.NS            0.037283
# CIPLA.NS           0.036707
# TCS.NS             0.032001
# BAJAJ-AUTO.NS      0.025892
# RELIANCE.NS        0.023023
# EICHERMOT.NS       0.018686
# M&M.NS             0.018647
# WIPRO.NS           0.018608
# BRITANNIA.NS       0.012949

# %%
#display(final_df)
#df = yf.download(tickers=list(map(ns, indices)), period='1d',interval='15m')
